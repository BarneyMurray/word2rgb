# %%
import torch
from torch import nn
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
import matplotlib.pyplot as plt

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertForSequenceClassification.from_pretrained("./results/model")

# %%
inputs = tokenizer("hot pink", return_tensors="pt")

with torch.no_grad():
    logits = model(**inputs).logits
    s = nn.Sigmoid()
    preds = s(logits).tolist()

print([v*255 for v in preds[0]])
plt.imshow([[tuple(preds[0])]])
# Out:
# [229.46576535701752, 38.35847049951553, 149.9118509888649]

# %%
inputs = tokenizer("snotty", return_tensors="pt")

with torch.no_grad():
    logits = model(**inputs).logits
    s = nn.Sigmoid()
    preds = s(logits).tolist()

print([v*255 for v in preds[0]])
plt.imshow([[tuple(preds[0])]])
# Out:
# [189.44582641124725, 183.76476645469666, 106.84269726276398]
